# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Running on device: {device}')
# Out:
# Running on device: cuda

# %%
# %pip install -U ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="qygztmDjlZEGySfvzU0z")
project = rf.workspace("cadyzedevelopmenthub").project("card-detection-zk7wu")
version = project.version(12)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import os
os.chdir(r"C:\Users\Amir\Card-Detection-12")
print("Changed working directory to:", os.getcwd())

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="./data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.89  Python-3.11.11 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4080, 16376MiB)
# ...

# %%
# !yolo export model=yolo11n.pt
# Out:
# WARNING âš ï¸� 'format' argument is missing. Using default 'format=torchscript'.
# Ultralytics 8.3.89 ðŸš€ Python-3.11.11 torch-2.6.0+cu126 CPU (Intel Core(TM) i9-14900KF)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
#
# TorchScript: starting export with torch 2.6.0+cu126...
# TorchScript: export success âœ… 1.0s, saved as 'yolo11n.torchscript' (10.5 MB)
#
# Export complete (1.3s)
# Results saved to C:\Users\Amir\Card-Detection-12
# Predict:         yolo predict task=detect model=yolo11n.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolo11n.torchscript imgsz=640 data=/usr/src/ultralytics/ultralytics/cfg/datasets/coco.yaml
# Visualize:       https://netron.app
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/export

# %%
# !wget https://ejtech.io/code/yolo_detect.py
# Out:
# --2025-03-14 14:40:15--  https://ejtech.io/code/yolo_detect.py
# Loaded CA certificate '/usr/ssl/certs/ca-bundle.crt'
# Resolving ejtech.io (ejtech.io)... 13.33.141.113, 13.33.141.37, 13.33.141.41, ...
# Connecting to ejtech.io (ejtech.io)|13.33.141.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://www.ejtech.io/code/yolo_detect.py [following]
# --2025-03-14 14:40:16--  https://www.ejtech.io/code/yolo_detect.py
# Resolving www.ejtech.io (www.ejtech.io)... 13.33.141.113, 13.33.141.41, 13.33.141.37, ...
# Connecting to www.ejtech.io (www.ejtech.io)|13.33.141.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9685 (9.5K) [text/plain]
# Saving to: 'yolo_detect.py'
#
#      0K .........                                             100% 20.4M=0s
#
# 2025-03-14 14:40:16 (20.4 MB/s) - 'yolo_detect.py' saved [9685/9685]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="qygztmDjlZEGySfvzU0z")
project = rf.workspace("haw-aocnc").project("playing-cards-lvix5")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Playing-Cards-2 in yolov11:: 100%|██████████| 504/504 [00:00<00:00, 3276.59it/s]

# %%
from ultralytics import YOLO

# Load the trained model
model = YOLO(r"C:\Users\Amir\Card-Detection-12\best.pt")

# Run predictions and save annotated images
results = model.predict(
    source=r"C:\Users\Amir\Data2\train\images",  # Folder of images
    imgsz=640,
    conf=0.25,
    save=True  # Annotated images saved automatically
)
# Out:
# image 1/212 C:\Users\Amir\Data2\train\images\001_jpg.rf.2b2d2f4280489bb3f092704e021d136c.jpg: 640x640 2 6Ss, 1 8S, 5.5ms
# image 2/212 C:\Users\Amir\Data2\train\images\001_jpg.rf.5d251d8d428ebeec54445a26f0d5863a.jpg: 640x640 2 6Ss, 2 8Ss, 6.5ms
# image 3/212 C:\Users\Amir\Data2\train\images\001_jpg.rf.e5207b9e1c1fa52c73d89803cdb694af.jpg: 640x640 1 6S, 2 8Ss, 6.2ms
# image 4/212 C:\Users\Amir\Data2\train\images\005_jpg.rf.89ffeffba902774a8aeb70b99e235791.jpg: 640x640 1 KD, 5.7ms
# image 5/212 C:\Users\Amir\Data2\train\images\005_jpg.rf.c539c74374758dd122e06a852d62e66c.jpg: 640x640 2 KDs, 5.7ms
# image 6/212 C:\Users\Amir\Data2\train\images\005_jpg.rf.fb0f28003ab88b1bb0345a369bba7099.jpg: 640x640 1 AD, 2 KDs, 5.8ms
# image 7/212 C:\Users\Amir\Data2\train\images\006_jpg.rf.336cb371c5c581cf1d64d3fb67bf4833.jpg: 640x640 4 QDs, 6.4ms
# image 8/212 C:\Users\Amir\Data2\train\images\006_jpg.rf.8ea8eef02420e14a373633d2876b4e6f.jpg: 640x640 1 JH, 2 QHs, 8.2ms
# ...

# %%
from ultralytics import YOLO

# Load the trained model (best.pt) as starting point
model = YOLO(r"C:\Users\Amir\Card-Detection-12\best.pt")

# %%
results = model.train(
    data=r"C:\Users\Amir\Data2\data.yaml",  # Path to new dataset config
    epochs=100,                            # Number of training epochs (adjust as needed)
    imgsz=640,                             # Image size (same as before)
    batch=8,                               # Batch size (adjust based on GPU/CPU capacity)
    patience=20,                           # Early stopping if performance stops improving
    optimizer='auto',                      # Optional: Let YOLO choose best optimizer
    save=True                              # Save final and best models
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.91 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.89  Python-3.11.11 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4080, 16376MiB)
# ...
